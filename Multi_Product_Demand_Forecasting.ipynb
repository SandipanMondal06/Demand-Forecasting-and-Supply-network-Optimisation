# %% [markdown]
# ## Import Libraries

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.5 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.5.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (3.0.12)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.0.2)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (2.5.0)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (75.2.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.12/dist-packages (from pmdarima) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.19->pmdarima) (2025.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.17.0)
# Downloading pmdarima-2.1.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 9.6 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.1.1

# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
from pmdarima import auto_arima

from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings("ignore")

np.random.seed(42)

# %% [markdown]
# ## Data Loaded

# %%
df = pd.read_csv("demand_data.csv", parse_dates=["week"])

# Extract numeric ids for correct sorting
df["store_num"] = df["store"].str.extract(r"(\d+)").astype(int)
df["product_num"] = df["product"].str.extract(r"(\d+)").astype(int)

# Correct sorting
df = df.sort_values(["store_num", "product_num", "week"])

# Drop helper columns
df = df.drop(columns=["store_num", "product_num"])

# %%
df
# Out:
#             week     store     product  demand
# 0     2024-01-07   store_1   product_1      69
# 1     2024-01-14   store_1   product_1      64
# 2     2024-01-21   store_1   product_1      91
# 3     2024-01-28   store_1   product_1      95
# 4     2024-02-04   store_1   product_1      73
# ...          ...       ...         ...     ...
# 19995 2025-11-02  store_10  product_20     168
# 19996 2025-11-09  store_10  product_20     143
# 19997 2025-11-16  store_10  product_20     131
# 19998 2025-11-23  store_10  product_20     145
# 19999 2025-11-30  store_10  product_20     167
#
# [20000 rows x 4 columns]

# %% [markdown]
# ## SARIMA Parameters estimation

# %%
results = []

for (store, product), g in df.groupby(["store", "product"]):

    series = g["demand"].values

    # ---- Minimum length safeguard ----
    if len(series) < 20:
        continue

    try:
        model = auto_arima(
            series,
            seasonal=True,
            m=4,                       # 4-week seasonality
            d=None,                    # auto detect
            D=None,                    # auto detect
            start_p=0, start_q=0,
            max_p=3, max_q=3,
            start_P=0, start_Q=0,
            max_P=2, max_Q=2,
            with_intercept=True,
            trace=True,
            error_action="ignore",
            suppress_warnings=True,
            stepwise=True
        )

        order = model.order                 # (p, d, q)
        seasonal_order = model.seasonal_order  # (P, D, Q, s)

        results.append({
            "store": store,
            "product": product,
            "p": order[0],
            "d": order[1],
            "q": order[2],
            "P": seasonal_order[0],
            "D": seasonal_order[1],
            "Q": seasonal_order[2],
            "s": seasonal_order[3],
            "AIC": model.aic()
        })

    except Exception as e:
        print(f"Model failed for {store}-{product}: {e}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=624.718, Time=0.62 sec
#  ARIMA(3,1,1)(0,0,2)[4] intercept   : AIC=623.408, Time=0.91 sec
#  ARIMA(3,1,1)(0,0,1)[4] intercept   : AIC=624.871, Time=0.55 sec
#  ARIMA(3,1,1)(1,0,2)[4] intercept   : AIC=625.566, Time=1.09 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=624.336, Time=0.68 sec
#  ARIMA(2,1,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(3,1,2)(0,0,2)[4] intercept   : AIC=624.876, Time=2.73 sec
#  ARIMA(2,1,2)(0,0,2)[4] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(3,1,1)(0,0,2)[4]             : AIC=690.502, Time=0.26 sec
#
# Best model:  ARIMA(3,1,1)(0,0,2)[4] intercept
# Total fit time: 19.405 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=626.117, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=608.153, Time=0.14 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=631.523, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=624.841, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=606.087, Time=0.19 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=606.485, Time=0.12 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=608.085, Time=0.21 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=608.086, Time=0.37 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=606.170, Time=0.17 sec
#  ARIMA(2,0,1)(2,1,0)[4] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(1,0,0)(2,1,0)[4]             : AIC=626.461, Time=0.08 sec
#
# Best model:  ARIMA(1,0,0)(2,1,0)[4] intercept
# Total fit time: 3.623 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=768.650, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=702.825, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=767.970, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=767.889, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=691.144, Time=0.18 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(2,0,0)[4] intercept   : AIC=709.276, Time=0.13 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=655.735, Time=0.27 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=663.429, Time=0.14 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=636.008, Time=0.91 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=634.544, Time=0.52 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=681.799, Time=0.16 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=686.913, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=676.142, Time=0.24 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=1.31 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=630.588, Time=2.57 sec
#  ARIMA(2,1,1)(0,0,1)[4] intercept   : AIC=654.717, Time=0.24 sec
#  ARIMA(2,1,1)(1,0,0)[4] intercept   : AIC=654.672, Time=0.25 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=636.966, Time=0.92 sec
#  ARIMA(2,1,1)(1,0,2)[4] intercept   : AIC=635.667, Time=0.83 sec
#  ARIMA(2,1,1)(0,0,0)[4] intercept   : AIC=653.184, Time=0.14 sec
#  ARIMA(2,1,1)(0,0,2)[4] intercept   : AIC=656.664, Time=0.38 sec
#  ARIMA(2,1,1)(2,0,0)[4] intercept   : AIC=655.164, Time=0.60 sec
#  ARIMA(2,1,1)(2,0,2)[4] intercept   : AIC=inf, Time=1.04 sec
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=630.712, Time=0.56 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=623.597, Time=0.73 sec
#  ARIMA(3,1,1)(0,0,1)[4] intercept   : AIC=622.051, Time=0.54 sec
#  ARIMA(3,1,1)(0,0,0)[4] intercept   : AIC=646.112, Time=0.17 sec
#  ARIMA(3,1,1)(0,0,2)[4] intercept   : AIC=623.473, Time=0.77 sec
#  ARIMA(3,1,1)(1,0,0)[4] intercept   : AIC=641.686, Time=0.49 sec
#  ARIMA(3,1,1)(1,0,2)[4] intercept   : AIC=625.488, Time=0.90 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(3,1,2)(0,0,1)[4] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(2,1,2)(0,0,1)[4] intercept   : AIC=645.313, Time=0.42 sec
#  ARIMA(3,1,1)(0,0,1)[4]             : AIC=679.549, Time=0.26 sec
#
# Best model:  ARIMA(3,1,1)(0,0,1)[4] intercept
# Total fit time: 19.924 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=654.847, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=638.970, Time=0.31 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=1.52 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=660.099, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=656.832, Time=0.08 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=627.355, Time=0.57 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=610.169, Time=0.90 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(1,0,0)(2,1,2)[4] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(1,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=608.175, Time=0.35 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=625.357, Time=0.16 sec
#  ARIMA(0,0,0)(2,1,2)[4] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=637.297, Time=0.08 sec
#  ARIMA(0,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,0,1)(2,1,1)[4] intercept   : AIC=610.169, Time=0.48 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=612.085, Time=0.82 sec
#  ARIMA(0,0,0)(2,1,1)[4]             : AIC=inf, Time=0.39 sec
#
# Best model:  ARIMA(0,0,0)(2,1,1)[4] intercept
# Total fit time: 8.848 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=443.281, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=406.950, Time=0.18 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=588.360, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=445.235, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=392.904, Time=0.34 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=371.277, Time=0.73 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(1,0,0)(2,1,2)[4] intercept   : AIC=inf, Time=1.01 sec
#  ARIMA(1,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=1.17 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=1.24 sec
#  ARIMA(2,0,0)(2,1,1)[4] intercept   : AIC=370.783, Time=2.32 sec
#  ARIMA(2,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=393.928, Time=0.44 sec
#  ARIMA(2,0,0)(2,1,2)[4] intercept   : AIC=373.613, Time=1.03 sec
#  ARIMA(2,0,0)(1,1,0)[4] intercept   : AIC=407.850, Time=0.32 sec
#  ARIMA(2,0,0)(1,1,2)[4] intercept   : AIC=372.812, Time=0.80 sec
#  ARIMA(3,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=1.02 sec
#  ARIMA(2,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.83 sec
#  ARIMA(3,0,1)(2,1,1)[4] intercept   : AIC=373.866, Time=1.23 sec
#  ARIMA(2,0,0)(2,1,1)[4]             : AIC=inf, Time=0.76 sec
#
# Best model:  ARIMA(2,0,0)(2,1,1)[4] intercept
# Total fit time: 16.129 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=456.012, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=443.217, Time=0.13 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.28 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=566.472, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=457.941, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=430.612, Time=0.28 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.76 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=428.947, Time=0.29 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=441.678, Time=0.25 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=430.663, Time=0.26 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=432.140, Time=0.76 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=512.097, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 6.607 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=664.622, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=640.935, Time=0.13 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=628.446, Time=0.13 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=686.471, Time=0.01 sec
#  ARIMA(0,0,1)(0,1,0)[4] intercept   : AIC=666.571, Time=0.05 sec
#  ARIMA(0,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(0,0,1)(0,1,2)[4] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(1,1,0)[4] intercept   : AIC=641.039, Time=0.11 sec
#  ARIMA(0,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,0,0)(0,1,1)[4] intercept   : AIC=626.669, Time=0.08 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,1,2)[4] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=640.728, Time=0.12 sec
#  ARIMA(0,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=628.444, Time=0.27 sec
#  ARIMA(1,0,1)(0,1,1)[4] intercept   : AIC=630.444, Time=0.51 sec
#  ARIMA(0,0,0)(0,1,1)[4]             : AIC=686.618, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,1,1)[4] intercept
# Total fit time: 4.070 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=775.864, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=707.807, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=775.149, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=777.337, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=693.248, Time=0.19 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,1,0)(2,0,0)[4] intercept   : AIC=694.316, Time=0.12 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=681.211, Time=0.30 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=687.325, Time=0.21 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=652.743, Time=0.46 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=687.329, Time=0.19 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=685.337, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=684.191, Time=0.25 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=2.92 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=630.492, Time=1.01 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=650.090, Time=0.35 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=630.056, Time=0.84 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=635.068, Time=0.92 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=632.024, Time=0.77 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=628.821, Time=0.97 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=624.954, Time=0.68 sec
#  ARIMA(3,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(3,1,1)(1,0,0)[4] intercept   : AIC=648.766, Time=0.61 sec
#  ARIMA(3,1,1)(1,0,2)[4] intercept   : AIC=623.304, Time=0.86 sec
#  ARIMA(3,1,1)(0,0,2)[4] intercept   : AIC=621.697, Time=0.89 sec
#  ARIMA(2,1,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(3,1,2)(0,0,2)[4] intercept   : AIC=626.010, Time=2.78 sec
#  ARIMA(2,1,2)(0,0,2)[4] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(3,1,1)(0,0,2)[4]             : AIC=684.643, Time=0.30 sec
#
# Best model:  ARIMA(3,1,1)(0,0,2)[4] intercept
# Total fit time: 23.068 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=634.247, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=618.322, Time=0.18 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=591.535, Time=0.12 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=680.022, Time=0.01 sec
#  ARIMA(0,0,1)(0,1,0)[4] intercept   : AIC=636.031, Time=0.04 sec
#  ARIMA(0,0,1)(1,1,1)[4] intercept   : AIC=593.481, Time=0.24 sec
#  ARIMA(0,0,1)(0,1,2)[4] intercept   : AIC=593.468, Time=0.18 sec
#  ARIMA(0,0,1)(1,1,0)[4] intercept   : AIC=618.453, Time=0.11 sec
#  ARIMA(0,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(0,0,0)(0,1,1)[4] intercept   : AIC=589.790, Time=0.08 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=591.720, Time=0.30 sec
#  ARIMA(0,0,0)(0,1,2)[4] intercept   : AIC=591.702, Time=0.15 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=617.606, Time=0.12 sec
#  ARIMA(0,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=591.519, Time=0.37 sec
#  ARIMA(1,0,1)(0,1,1)[4] intercept   : AIC=593.467, Time=0.60 sec
#  ARIMA(0,0,0)(0,1,1)[4]             : AIC=681.191, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,1,1)[4] intercept
# Total fit time: 3.744 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=450.000, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=429.075, Time=0.08 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=449.237, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=451.962, Time=0.03 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=414.999, Time=0.18 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.59 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=413.028, Time=0.09 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=427.203, Time=0.05 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=414.977, Time=0.12 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=414.984, Time=0.30 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=420.550, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 3.071 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=435.213, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=410.479, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=434.762, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=436.606, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=407.030, Time=0.14 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=405.584, Time=0.09 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=409.585, Time=0.05 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.53 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=407.024, Time=0.27 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=409.024, Time=1.48 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=410.964, Time=0.07 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 4.500 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=644.541, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=618.280, Time=0.27 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=650.030, Time=0.03 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=646.000, Time=0.13 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=613.371, Time=0.27 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=611.481, Time=0.15 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=616.467, Time=0.07 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=613.372, Time=0.17 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=615.371, Time=0.40 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=635.922, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 4.103 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=790.136, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=713.813, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=789.031, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=786.418, Time=0.06 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=676.845, Time=0.25 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=667.278, Time=0.69 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=665.941, Time=0.72 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=758.907, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=667.512, Time=0.65 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=729.123, Time=0.22 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=667.117, Time=0.77 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=655.726, Time=0.44 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=729.832, Time=0.16 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=697.633, Time=0.18 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=657.644, Time=0.82 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=657.678, Time=0.74 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=740.868, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=707.053, Time=0.23 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=669.153, Time=0.32 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=nan sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=622.945, Time=2.03 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=622.290, Time=0.95 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=672.076, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=623.040, Time=0.68 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=635.609, Time=0.38 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=625.561, Time=0.80 sec
#  ARIMA(3,1,1)(0,0,1)[4] intercept   : AIC=620.310, Time=0.62 sec
#  ARIMA(3,1,1)(0,0,0)[4] intercept   : AIC=668.878, Time=0.15 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=620.406, Time=0.69 sec
#  ARIMA(3,1,1)(0,0,2)[4] intercept   : AIC=620.080, Time=0.87 sec
#  ARIMA(3,1,1)(1,0,2)[4] intercept   : AIC=622.307, Time=0.90 sec
#  ARIMA(2,1,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,2)(0,0,2)[4] intercept   : AIC=621.886, Time=0.91 sec
#  ARIMA(2,1,2)(0,0,2)[4] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(3,1,1)(0,0,2)[4]             : AIC=680.085, Time=0.33 sec
#
# Best model:  ARIMA(3,1,1)(0,0,2)[4] intercept
# Total fit time: 18.933 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=828.562, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=717.127, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=826.697, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=829.361, Time=0.06 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=668.232, Time=0.48 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=784.195, Time=0.11 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=2.06 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=669.862, Time=1.71 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=762.467, Time=0.37 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,1,0)(1,0,1)[4]             : AIC=inf, Time=0.25 sec
#
# Best model:  ARIMA(1,1,0)(1,0,1)[4] intercept
# Total fit time: 8.811 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=795.827, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=689.209, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=793.978, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=796.889, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=630.713, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=754.596, Time=0.12 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=629.257, Time=0.62 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=629.422, Time=0.67 sec
#  ARIMA(0,1,0)(2,0,1)[4] intercept   : AIC=653.147, Time=0.34 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=617.002, Time=0.54 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=618.279, Time=0.52 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=641.813, Time=0.30 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=673.113, Time=0.23 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=617.041, Time=0.61 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=2.62 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.90 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=602.258, Time=0.92 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,1,1)(2,0,0)[4] intercept   : AIC=598.262, Time=0.86 sec
#  ARIMA(3,1,1)(1,0,0)[4] intercept   : AIC=607.856, Time=0.49 sec
#  ARIMA(2,1,1)(2,0,0)[4] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(3,1,2)(2,0,0)[4] intercept   : AIC=599.636, Time=1.02 sec
#  ARIMA(2,1,2)(2,0,0)[4] intercept   : AIC=632.075, Time=0.79 sec
#  ARIMA(3,1,1)(2,0,0)[4]             : AIC=625.685, Time=0.39 sec
#
# Best model:  ARIMA(3,1,1)(2,0,0)[4] intercept
# Total fit time: 17.640 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=407.404, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=375.256, Time=0.13 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=446.111, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=409.302, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=373.161, Time=0.19 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=371.442, Time=0.11 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=373.272, Time=0.07 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=1.85 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=373.018, Time=0.41 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=367.736, Time=1.32 sec
#  ARIMA(1,0,1)(1,1,0)[4] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(1,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(2,0,1)(2,1,0)[4] intercept   : AIC=369.877, Time=0.90 sec
#  ARIMA(1,0,2)(2,1,0)[4] intercept   : AIC=368.963, Time=0.87 sec
#  ARIMA(0,0,2)(2,1,0)[4] intercept   : AIC=371.554, Time=0.24 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=372.732, Time=0.26 sec
#  ARIMA(2,0,2)(2,1,0)[4] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(1,0,1)(2,1,0)[4]             : AIC=inf, Time=0.54 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[4] intercept
# Total fit time: 12.028 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=850.556, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=711.886, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=848.599, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=851.888, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=700.349, Time=0.29 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=674.571, Time=0.51 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=789.695, Time=0.12 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.94 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=762.311, Time=0.22 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=1.81 sec
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=1.62 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(1,1,0)(1,0,1)[4]             : AIC=inf, Time=0.31 sec
#
# Best model:  ARIMA(1,1,0)(1,0,1)[4] intercept
# Total fit time: 9.761 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=760.357, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=705.907, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=759.429, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=760.065, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=687.786, Time=0.15 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(2,0,0)[4] intercept   : AIC=699.034, Time=0.11 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=679.136, Time=0.26 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=690.412, Time=0.14 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.67 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=638.820, Time=0.78 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=645.463, Time=0.37 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=625.135, Time=0.87 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=624.149, Time=0.63 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=625.538, Time=0.98 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=660.165, Time=0.36 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=624.157, Time=2.22 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=627.809, Time=1.36 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=625.176, Time=0.69 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(3,1,0)(1,0,1)[4]             : AIC=inf, Time=0.41 sec
#
# Best model:  ARIMA(3,1,0)(1,0,1)[4] intercept
# Total fit time: 14.069 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=741.007, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=699.405, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=739.051, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=738.662, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=679.929, Time=0.19 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=650.611, Time=0.60 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=655.767, Time=0.47 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=649.381, Time=0.55 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=706.724, Time=0.21 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=719.451, Time=0.07 sec
#  ARIMA(0,1,0)(1,0,2)[4] intercept   : AIC=672.381, Time=0.35 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=636.670, Time=0.60 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=679.467, Time=0.17 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=642.624, Time=0.90 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=682.519, Time=0.14 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=637.590, Time=0.55 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=610.754, Time=0.83 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=2.40 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=613.655, Time=1.59 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=610.195, Time=0.84 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=622.467, Time=0.58 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=628.964, Time=0.34 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=620.685, Time=0.94 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=619.266, Time=0.95 sec
#  ARIMA(3,1,0)(2,0,1)[4]             : AIC=inf, Time=0.82 sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[4] intercept
# Total fit time: 16.447 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=438.226, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=419.933, Time=0.14 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=566.996, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=440.222, Time=0.06 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=410.541, Time=0.30 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=409.010, Time=0.17 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=418.052, Time=0.08 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=410.384, Time=0.28 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=407.135, Time=1.08 sec
#  ARIMA(1,0,1)(1,1,0)[4] intercept   : AIC=413.518, Time=2.32 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(1,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(2,0,1)(2,1,0)[4] intercept   : AIC=409.825, Time=0.86 sec
#  ARIMA(1,0,2)(2,1,0)[4] intercept   : AIC=410.386, Time=0.95 sec
#  ARIMA(0,0,2)(2,1,0)[4] intercept   : AIC=410.593, Time=0.26 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=410.868, Time=0.35 sec
#  ARIMA(2,0,2)(2,1,0)[4] intercept   : AIC=409.630, Time=0.97 sec
#  ARIMA(1,0,1)(2,1,0)[4]             : AIC=inf, Time=0.58 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[4] intercept
# Total fit time: 13.261 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=762.147, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=702.303, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=760.166, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=758.662, Time=0.07 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=676.371, Time=0.19 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=660.540, Time=0.39 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=659.513, Time=0.33 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=734.497, Time=0.10 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=660.761, Time=0.43 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=710.414, Time=0.20 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=693.794, Time=0.23 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=644.369, Time=0.29 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=696.976, Time=0.15 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=677.874, Time=0.16 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=646.230, Time=0.49 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=646.278, Time=0.41 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=704.387, Time=0.08 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=680.207, Time=0.16 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=656.871, Time=0.49 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=2.56 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=624.039, Time=1.00 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.48 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=637.931, Time=0.25 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=636.737, Time=0.91 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=627.114, Time=0.78 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=656.672, Time=0.15 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=656.926, Time=0.39 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=1.07 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=630.447, Time=0.67 sec
#  ARIMA(3,1,0)(1,0,1)[4]             : AIC=630.378, Time=0.56 sec
#
# Best model:  ARIMA(3,1,0)(1,0,1)[4] intercept
# Total fit time: 15.610 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=744.501, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=705.467, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=742.745, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=732.911, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=702.036, Time=0.16 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.43 sec
#  ARIMA(0,1,0)(2,0,0)[4] intercept   : AIC=729.656, Time=0.10 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=673.827, Time=0.24 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=675.184, Time=0.14 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=2.27 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=641.868, Time=1.30 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=653.039, Time=0.27 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=636.871, Time=0.88 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.93 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(3,1,0)(2,0,1)[4]             : AIC=inf, Time=0.70 sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[4] intercept
# Total fit time: 12.686 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=660.808, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=641.274, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=696.266, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=658.070, Time=0.08 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=612.403, Time=0.25 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=610.687, Time=0.17 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=645.313, Time=0.13 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=612.408, Time=0.23 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=inf, Time=1.09 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=698.845, Time=0.14 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 4.704 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=835.016, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=686.739, Time=0.94 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=833.045, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=836.598, Time=0.13 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=672.712, Time=0.51 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=657.580, Time=0.61 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=655.962, Time=0.22 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=769.649, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=657.555, Time=0.57 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=749.637, Time=0.24 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=697.582, Time=0.52 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=673.274, Time=0.22 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=650.166, Time=0.51 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=706.984, Time=0.13 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=685.299, Time=0.20 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=651.994, Time=0.81 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=651.960, Time=0.71 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=705.009, Time=0.07 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=703.560, Time=0.37 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=669.466, Time=0.38 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.82 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=615.960, Time=0.65 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=617.279, Time=0.42 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=633.384, Time=0.48 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=1.08 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=620.871, Time=0.82 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=644.086, Time=0.26 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=inf, Time=2.31 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=666.038, Time=1.03 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=620.820, Time=1.02 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=619.643, Time=0.72 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,0)(1,0,1)[4]             : AIC=inf, Time=0.60 sec
#
# Best model:  ARIMA(3,1,0)(1,0,1)[4] intercept
# Total fit time: 19.254 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=469.867, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=446.928, Time=0.15 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=593.467, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=468.922, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=439.743, Time=0.26 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.81 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=438.908, Time=0.17 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=445.914, Time=0.09 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=439.559, Time=0.19 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=438.714, Time=0.72 sec
#  ARIMA(1,0,1)(1,1,0)[4] intercept   : AIC=inf, Time=0.50 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(1,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(2,0,1)(2,1,0)[4] intercept   : AIC=439.274, Time=2.44 sec
#  ARIMA(1,0,2)(2,1,0)[4] intercept   : AIC=439.556, Time=1.66 sec
#  ARIMA(0,0,2)(2,1,0)[4] intercept   : AIC=441.140, Time=0.25 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=441.117, Time=0.34 sec
#  ARIMA(2,0,2)(2,1,0)[4] intercept   : AIC=inf, Time=0.92 sec
#  ARIMA(1,0,1)(2,1,0)[4]             : AIC=inf, Time=0.65 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[4] intercept
# Total fit time: 12.995 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=407.113, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=393.517, Time=0.14 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=387.403, Time=0.10 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=558.720, Time=0.01 sec
#  ARIMA(0,0,1)(0,1,0)[4] intercept   : AIC=409.111, Time=0.04 sec
#  ARIMA(0,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(0,0,1)(0,1,2)[4] intercept   : AIC=388.930, Time=0.15 sec
#  ARIMA(0,0,1)(1,1,0)[4] intercept   : AIC=393.550, Time=0.14 sec
#  ARIMA(0,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,0,0)(0,1,1)[4] intercept   : AIC=385.591, Time=0.08 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,0,0)(0,1,2)[4] intercept   : AIC=387.040, Time=0.11 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=391.719, Time=0.16 sec
#  ARIMA(0,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=387.381, Time=0.12 sec
#  ARIMA(1,0,1)(0,1,1)[4] intercept   : AIC=388.670, Time=0.48 sec
#  ARIMA(0,0,0)(0,1,1)[4]             : AIC=532.418, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(0,1,1)[4] intercept
# Total fit time: 4.063 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=634.087, Time=0.02 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=609.272, Time=0.10 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=639.564, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=635.040, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=599.773, Time=0.20 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=597.806, Time=0.17 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=608.056, Time=0.09 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=599.767, Time=0.19 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=625.762, Time=0.22 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 4.223 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=458.353, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=429.007, Time=0.84 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=1.13 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=580.276, Time=0.02 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=460.222, Time=0.10 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=421.112, Time=0.74 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=401.364, Time=0.88 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.64 sec
#  ARIMA(1,0,0)(2,1,2)[4] intercept   : AIC=404.640, Time=0.94 sec
#  ARIMA(1,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.68 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(2,0,0)(2,1,1)[4] intercept   : AIC=407.275, Time=0.95 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,0,1)(2,1,1)[4] intercept   : AIC=403.139, Time=0.72 sec
#  ARIMA(2,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(1,0,0)(2,1,1)[4]             : AIC=inf, Time=0.82 sec
#
# Best model:  ARIMA(1,0,0)(2,1,1)[4] intercept
# Total fit time: 11.175 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=794.760, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=673.657, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=793.212, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=795.075, Time=0.03 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=660.162, Time=0.20 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=634.795, Time=0.57 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=632.801, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=739.617, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=634.787, Time=2.52 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=724.369, Time=0.59 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=1.05 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=665.963, Time=0.29 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=630.090, Time=0.54 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=699.160, Time=0.17 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=670.837, Time=0.16 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=632.062, Time=0.80 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=632.033, Time=1.07 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=709.350, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=699.502, Time=0.21 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=654.754, Time=0.25 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.96 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=616.836, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,1)[4] intercept   : AIC=657.813, Time=0.37 sec
#  ARIMA(2,1,1)(1,0,0)[4] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(2,1,1)(1,0,2)[4] intercept   : AIC=624.373, Time=0.94 sec
#  ARIMA(2,1,1)(0,0,0)[4] intercept   : AIC=657.616, Time=0.13 sec
#  ARIMA(2,1,1)(0,0,2)[4] intercept   : AIC=659.243, Time=0.46 sec
#  ARIMA(2,1,1)(2,0,0)[4] intercept   : AIC=inf, Time=1.69 sec
#  ARIMA(2,1,1)(2,0,2)[4] intercept   : AIC=618.710, Time=2.26 sec
#  ARIMA(1,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.54 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=617.130, Time=0.71 sec
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=620.797, Time=0.75 sec
#  ARIMA(1,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.69 sec
#  ARIMA(3,1,2)(1,0,1)[4] intercept   : AIC=632.068, Time=0.84 sec
#  ARIMA(2,1,1)(1,0,1)[4]             : AIC=614.281, Time=0.37 sec
#  ARIMA(2,1,1)(0,0,1)[4]             : AIC=680.153, Time=0.13 sec
#  ARIMA(2,1,1)(1,0,0)[4]             : AIC=653.861, Time=0.14 sec
#  ARIMA(2,1,1)(2,0,1)[4]             : AIC=616.280, Time=0.66 sec
#  ARIMA(2,1,1)(1,0,2)[4]             : AIC=616.307, Time=0.99 sec
#  ARIMA(2,1,1)(0,0,0)[4]             : AIC=684.859, Time=0.08 sec
#  ARIMA(2,1,1)(0,0,2)[4]             : AIC=680.641, Time=0.22 sec
#  ARIMA(2,1,1)(2,0,0)[4]             : AIC=637.681, Time=0.31 sec
#  ARIMA(2,1,1)(2,0,2)[4]             : AIC=inf, Time=0.70 sec
#  ARIMA(1,1,1)(1,0,1)[4]             : AIC=612.998, Time=0.34 sec
#  ARIMA(1,1,1)(0,0,1)[4]             : AIC=708.267, Time=0.09 sec
#  ARIMA(1,1,1)(1,0,0)[4]             : AIC=652.549, Time=0.14 sec
#  ARIMA(1,1,1)(2,0,1)[4]             : AIC=615.000, Time=0.58 sec
#  ARIMA(1,1,1)(1,0,2)[4]             : AIC=614.979, Time=0.66 sec
#  ARIMA(1,1,1)(0,0,0)[4]             : AIC=759.507, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,2)[4]             : AIC=695.703, Time=0.18 sec
#  ARIMA(1,1,1)(2,0,0)[4]             : AIC=636.762, Time=0.22 sec
#  ARIMA(1,1,1)(2,0,2)[4]             : AIC=inf, Time=1.93 sec
#  ARIMA(0,1,1)(1,0,1)[4]             : AIC=611.054, Time=1.28 sec
#  ARIMA(0,1,1)(0,0,1)[4]             : AIC=708.149, Time=0.15 sec
#  ARIMA(0,1,1)(1,0,0)[4]             : AIC=651.419, Time=0.16 sec
#  ARIMA(0,1,1)(2,0,1)[4]             : AIC=613.049, Time=0.61 sec
#  ARIMA(0,1,1)(1,0,2)[4]             : AIC=613.062, Time=0.38 sec
#  ARIMA(0,1,1)(0,0,0)[4]             : AIC=758.333, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,2)[4]             : AIC=694.815, Time=0.17 sec
#  ARIMA(0,1,1)(2,0,0)[4]             : AIC=634.766, Time=0.18 sec
#  ARIMA(0,1,1)(2,0,2)[4]             : AIC=inf, Time=0.42 sec
#  ARIMA(0,1,0)(1,0,1)[4]             : AIC=663.975, Time=0.14 sec
#  ARIMA(0,1,2)(1,0,1)[4]             : AIC=613.111, Time=0.69 sec
#  ARIMA(1,1,0)(1,0,1)[4]             : AIC=630.841, Time=0.23 sec
#  ARIMA(1,1,2)(1,0,1)[4]             : AIC=616.914, Time=0.57 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.75 sec
#
# Best model:  ARIMA(0,1,1)(1,0,1)[4]
# Total fit time: 36.318 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=831.790, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=745.605, Time=0.18 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=829.834, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=832.175, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=719.590, Time=0.23 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=704.567, Time=0.54 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=702.575, Time=0.31 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=796.301, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=704.568, Time=0.64 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=773.391, Time=0.21 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=724.717, Time=0.34 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=686.027, Time=0.52 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=746.266, Time=0.15 sec
# ...
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=437.627, Time=0.83 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=448.780, Time=0.69 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=466.609, Time=0.76 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=439.701, Time=0.94 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=452.319, Time=0.40 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=448.423, Time=0.93 sec
#  ARIMA(3,1,1)(1,0,2)[4] intercept   : AIC=440.274, Time=0.84 sec
#  ARIMA(2,1,1)(1,0,2)[4] intercept   : AIC=450.979, Time=0.78 sec
#  ARIMA(3,1,0)(1,0,2)[4]             : AIC=440.973, Time=0.54 sec
#
# Best model:  ARIMA(3,1,0)(1,0,2)[4] intercept
# Total fit time: 16.815 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=405.684, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=395.661, Time=0.07 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=405.499, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=404.362, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=395.271, Time=0.11 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=394.872, Time=0.08 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=395.283, Time=0.04 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.33 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=392.295, Time=0.10 sec
#  ARIMA(0,0,1)(1,1,0)[4] intercept   : AIC=392.446, Time=0.07 sec
#  ARIMA(0,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(0,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=1.12 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=390.102, Time=1.03 sec
#  ARIMA(1,0,1)(1,1,0)[4] intercept   : AIC=389.707, Time=0.24 sec
#  ARIMA(1,0,1)(0,1,0)[4] intercept   : AIC=395.909, Time=0.18 sec
#  ARIMA(1,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=1.11 sec
#  ARIMA(1,0,1)(0,1,1)[4] intercept   : AIC=379.787, Time=0.15 sec
#  ARIMA(1,0,1)(0,1,2)[4] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(1,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(2,0,1)(0,1,1)[4] intercept   : AIC=375.845, Time=0.19 sec
#  ARIMA(2,0,1)(0,1,0)[4] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(2,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(2,0,1)(0,1,2)[4] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(2,0,1)(1,1,0)[4] intercept   : AIC=387.442, Time=0.25 sec
#  ARIMA(2,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.98 sec
#  ARIMA(2,0,0)(0,1,1)[4] intercept   : AIC=373.861, Time=0.11 sec
#  ARIMA(2,0,0)(0,1,0)[4] intercept   : AIC=399.046, Time=0.05 sec
#  ARIMA(2,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(2,0,0)(0,1,2)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(2,0,0)(1,1,0)[4] intercept   : AIC=387.266, Time=0.10 sec
#  ARIMA(2,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.74 sec
#  ARIMA(3,0,0)(0,1,1)[4] intercept   : AIC=375.840, Time=0.13 sec
#  ARIMA(3,0,1)(0,1,1)[4] intercept   : AIC=377.836, Time=0.29 sec
#  ARIMA(2,0,0)(0,1,1)[4]             : AIC=387.604, Time=0.05 sec
#
# Best model:  ARIMA(2,0,0)(0,1,1)[4] intercept
# Total fit time: 14.832 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=446.720, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=431.274, Time=0.25 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=617.308, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=448.706, Time=0.05 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=426.588, Time=0.28 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.78 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=424.590, Time=0.87 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=429.385, Time=1.01 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=1.37 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=426.588, Time=0.28 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=428.589, Time=0.48 sec
#  ARIMA(0,0,0)(2,1,0)[4]             : AIC=504.673, Time=0.04 sec
#
# Best model:  ARIMA(0,0,0)(2,1,0)[4] intercept
# Total fit time: 6.959 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=729.209, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=668.407, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.23 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=727.280, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=727.192, Time=0.04 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=661.008, Time=0.19 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=642.682, Time=0.60 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=641.584, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=692.085, Time=0.11 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=642.457, Time=0.53 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=689.303, Time=0.17 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=642.121, Time=0.66 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=661.530, Time=0.23 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=637.645, Time=0.40 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=669.623, Time=0.09 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=661.036, Time=0.15 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=638.450, Time=0.76 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.65 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=681.498, Time=0.09 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=669.651, Time=0.21 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=656.517, Time=0.27 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=637.971, Time=0.93 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.62 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=624.482, Time=0.53 sec
#  ARIMA(2,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(2,1,1)(1,0,0)[4] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=623.621, Time=2.85 sec
#  ARIMA(2,1,1)(2,0,0)[4] intercept   : AIC=inf, Time=1.03 sec
#  ARIMA(2,1,1)(2,0,2)[4] intercept   : AIC=624.798, Time=0.90 sec
#  ARIMA(2,1,1)(1,0,2)[4] intercept   : AIC=625.611, Time=0.85 sec
#  ARIMA(1,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.66 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=636.418, Time=1.00 sec
#  ARIMA(2,1,2)(2,0,1)[4] intercept   : AIC=inf, Time=1.20 sec
#  ARIMA(1,1,2)(2,0,1)[4] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=622.612, Time=0.97 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=628.442, Time=0.60 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.91 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=637.722, Time=0.29 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,1,0)(2,0,1)[4]             : AIC=inf, Time=0.51 sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[4] intercept
# Total fit time: 22.182 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=800.199, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=713.101, Time=0.25 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.58 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=798.678, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=799.913, Time=0.10 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=704.305, Time=0.86 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=681.246, Time=1.19 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=679.528, Time=0.57 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=751.241, Time=0.21 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=681.427, Time=0.63 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=748.224, Time=0.15 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.44 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=703.494, Time=0.18 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=655.938, Time=0.33 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=708.135, Time=0.15 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=678.440, Time=0.17 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=656.176, Time=0.99 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=655.346, Time=0.71 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=706.676, Time=0.26 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=656.071, Time=0.90 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=626.759, Time=0.72 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=inf, Time=0.72 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=624.386, Time=0.67 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.45 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=650.388, Time=0.38 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=623.283, Time=0.81 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=inf, Time=0.75 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=626.033, Time=1.46 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=626.942, Time=2.82 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=660.422, Time=0.87 sec
#  ARIMA(3,1,0)(2,0,1)[4]             : AIC=647.636, Time=0.64 sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[4] intercept
# Total fit time: 19.006 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=568.869, Time=0.01 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=554.091, Time=0.09 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=568.876, Time=0.01 sec
#  ARIMA(1,0,0)(0,1,0)[4] intercept   : AIC=570.867, Time=0.04 sec
#  ARIMA(1,0,0)(2,1,0)[4] intercept   : AIC=551.029, Time=0.14 sec
#  ARIMA(1,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(1,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(0,0,0)(2,1,0)[4] intercept   : AIC=549.332, Time=0.12 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=552.222, Time=0.06 sec
#  ARIMA(0,0,0)(2,1,1)[4] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,1)(2,1,0)[4] intercept   : AIC=550.956, Time=0.14 sec
#  ARIMA(1,0,1)(2,1,0)[4] intercept   : AIC=545.841, Time=0.47 sec
#  ARIMA(1,0,1)(1,1,0)[4] intercept   : AIC=inf, Time=0.49 sec
#  ARIMA(1,0,1)(2,1,1)[4] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(1,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.57 sec
#  ARIMA(2,0,1)(2,1,0)[4] intercept   : AIC=547.541, Time=0.76 sec
#  ARIMA(1,0,2)(2,1,0)[4] intercept   : AIC=547.542, Time=0.46 sec
#  ARIMA(0,0,2)(2,1,0)[4] intercept   : AIC=551.840, Time=0.16 sec
#  ARIMA(2,0,0)(2,1,0)[4] intercept   : AIC=552.110, Time=0.23 sec
#  ARIMA(2,0,2)(2,1,0)[4] intercept   : AIC=inf, Time=0.55 sec
#  ARIMA(1,0,1)(2,1,0)[4]             : AIC=549.536, Time=0.40 sec
#
# Best model:  ARIMA(1,0,1)(2,1,0)[4] intercept
# Total fit time: 7.659 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=761.819, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=688.836, Time=0.10 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=759.956, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=761.157, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=659.982, Time=0.22 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=639.740, Time=2.28 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.99 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=643.226, Time=1.09 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=639.895, Time=0.72 sec
#  ARIMA(0,1,0)(2,0,1)[4] intercept   : AIC=inf, Time=0.73 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=628.694, Time=0.84 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.63 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=645.187, Time=0.25 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=629.579, Time=0.89 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=669.466, Time=0.15 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=628.707, Time=0.78 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=625.265, Time=0.87 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=628.942, Time=0.58 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=646.726, Time=0.39 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=1.00 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=625.328, Time=0.29 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=inf, Time=0.85 sec
#  ARIMA(3,1,1)(2,0,1)[4] intercept   : AIC=628.654, Time=2.52 sec
#  ARIMA(2,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=1.78 sec
#  ARIMA(3,1,0)(2,0,1)[4]             : AIC=inf, Time=0.64 sec
#
# Best model:  ARIMA(3,1,0)(2,0,1)[4] intercept
# Total fit time: 18.950 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=784.992, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=710.742, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=783.180, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=782.817, Time=0.05 sec
#  ARIMA(1,1,0)(2,0,0)[4] intercept   : AIC=696.890, Time=0.21 sec
#  ARIMA(1,1,0)(2,0,1)[4] intercept   : AIC=680.327, Time=0.28 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=678.647, Time=0.23 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=744.748, Time=0.07 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=680.122, Time=0.39 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=738.000, Time=0.22 sec
#  ARIMA(1,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.61 sec
#  ARIMA(0,1,0)(1,0,1)[4] intercept   : AIC=710.362, Time=0.34 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=671.617, Time=0.33 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=715.689, Time=0.16 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=699.025, Time=0.19 sec
#  ARIMA(2,1,0)(2,0,1)[4] intercept   : AIC=673.491, Time=0.74 sec
#  ARIMA(2,1,0)(1,0,2)[4] intercept   : AIC=673.402, Time=0.74 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=728.984, Time=0.14 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=714.838, Time=0.24 sec
#  ARIMA(2,1,0)(2,0,0)[4] intercept   : AIC=689.635, Time=0.27 sec
#  ARIMA(2,1,0)(2,0,2)[4] intercept   : AIC=inf, Time=0.79 sec
#  ARIMA(3,1,0)(1,0,1)[4] intercept   : AIC=641.317, Time=0.68 sec
#  ARIMA(3,1,0)(0,0,1)[4] intercept   : AIC=inf, Time=0.46 sec
#  ARIMA(3,1,0)(1,0,0)[4] intercept   : AIC=660.848, Time=0.40 sec
#  ARIMA(3,1,0)(2,0,1)[4] intercept   : AIC=642.967, Time=0.90 sec
#  ARIMA(3,1,0)(1,0,2)[4] intercept   : AIC=643.827, Time=2.28 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=670.901, Time=0.27 sec
#  ARIMA(3,1,0)(0,0,2)[4] intercept   : AIC=641.483, Time=1.37 sec
#  ARIMA(3,1,0)(2,0,0)[4] intercept   : AIC=645.383, Time=0.80 sec
#  ARIMA(3,1,0)(2,0,2)[4] intercept   : AIC=645.980, Time=1.00 sec
#  ARIMA(3,1,1)(1,0,1)[4] intercept   : AIC=643.050, Time=0.73 sec
#  ARIMA(2,1,1)(1,0,1)[4] intercept   : AIC=inf, Time=0.40 sec
#  ARIMA(3,1,0)(1,0,1)[4]             : AIC=inf, Time=0.51 sec
#
# Best model:  ARIMA(3,1,0)(1,0,1)[4] intercept
# Total fit time: 16.231 seconds
# Performing stepwise search to minimize aic
#  ARIMA(0,0,0)(0,1,0)[4] intercept   : AIC=454.172, Time=0.03 sec
#  ARIMA(1,0,0)(1,1,0)[4] intercept   : AIC=439.182, Time=0.18 sec
#  ARIMA(0,0,1)(0,1,1)[4] intercept   : AIC=415.582, Time=0.13 sec
#  ARIMA(0,0,0)(0,1,0)[4]             : AIC=613.699, Time=0.01 sec
#  ARIMA(0,0,1)(0,1,0)[4] intercept   : AIC=456.136, Time=0.04 sec
#  ARIMA(0,0,1)(1,1,1)[4] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(0,0,1)(0,1,2)[4] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,0,1)(1,1,0)[4] intercept   : AIC=439.182, Time=0.14 sec
#  ARIMA(0,0,1)(1,1,2)[4] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(0,0,0)(0,1,1)[4] intercept   : AIC=413.849, Time=0.10 sec
#  ARIMA(0,0,0)(1,1,1)[4] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,0,0)(0,1,2)[4] intercept   : AIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(1,1,0)[4] intercept   : AIC=437.240, Time=0.10 sec
#  ARIMA(0,0,0)(1,1,2)[4] intercept   : AIC=inf, Time=0.60 sec
#  ARIMA(1,0,0)(0,1,1)[4] intercept   : AIC=415.549, Time=0.29 sec
#  ARIMA(1,0,1)(0,1,1)[4] intercept   : AIC=417.106, Time=0.58 sec
#  ARIMA(0,0,0)(0,1,1)[4]             : AIC=580.912, Time=0.05 sec
#
# Best model:  ARIMA(0,0,0)(0,1,1)[4] intercept
# Total fit time: 4.872 seconds

# %%
results
# Out:
# [{'store': 'store_1',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(619.8393581951493)},
#  {'store': 'store_1',
#   'product': 'product_10',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(401.28770992442514)},
#  {'store': 'store_1',
#   'product': 'product_11',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(411.2924561607814)},
#  {'store': 'store_1',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(411.80178660826596)},
#  {'store': 'store_1',
#   'product': 'product_13',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(659.0881513758893)},
#  {'store': 'store_1',
#   'product': 'product_14',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(413.78243893854426)},
#  {'store': 'store_1',
#   'product': 'product_15',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(622.7012129174144)},
#  {'store': 'store_1',
#   'product': 'product_16',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(419.921640962917)},
#  {'store': 'store_1',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(397.895190272926)},
#  {'store': 'store_1',
#   'product': 'product_18',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(654.7436014191144)},
#  {'store': 'store_1',
#   'product': 'product_19',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(634.1653818843367)},
#  {'store': 'store_1',
#   'product': 'product_2',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(613.3738887798398)},
#  {'store': 'store_1',
#   'product': 'product_20',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(390.57577300806156)},
#  {'store': 'store_1',
#   'product': 'product_3',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(633.3604706032088)},
#  {'store': 'store_1',
#   'product': 'product_4',
#   'p': 2,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(648.7486502190017)},
#  {'store': 'store_1',
#   'product': 'product_5',
#   'p': 2,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(650.3344499214667)},
#  {'store': 'store_1',
#   'product': 'product_6',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(595.0910949365638)},
#  {'store': 'store_1',
#   'product': 'product_7',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(393.662442082519)},
#  {'store': 'store_1',
#   'product': 'product_8',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(446.7039586834201)},
#  {'store': 'store_1',
#   'product': 'product_9',
#   'p': 3,
#   'd': 1,
#   'q': 3,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(607.8685153343855)},
#  {'store': 'store_10',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(401.12631187498187)},
#  {'store': 'store_10',
#   'product': 'product_10',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(706.20861395141)},
#  {'store': 'store_10',
#   'product': 'product_11',
#   'p': 1,
#   'd': 1,
#   'q': 2,
#   'P': 1,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(628.113202794457)},
#  {'store': 'store_10',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(645.6667596222662)},
#  {'store': 'store_10',
#   'product': 'product_13',
#   'p': 0,
#   'd': 1,
#   'q': 2,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(654.9519670950743)},
#  {'store': 'store_10',
#   'product': 'product_14',
#   'p': 1,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(605.1275344164602)},
#  {'store': 'store_10',
#   'product': 'product_15',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(599.9203141767591)},
#  {'store': 'store_10',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(440.6267861263967)},
#  {'store': 'store_10',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(396.83673239734304)},
#  {'store': 'store_10',
#   'product': 'product_18',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(623.4076645705491)},
#  {'store': 'store_10',
#   'product': 'product_19',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(606.0873234959977)},
#  {'store': 'store_10',
#   'product': 'product_2',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(622.0510273624027)},
#  {'store': 'store_10',
#   'product': 'product_20',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(608.1753971749107)},
#  {'store': 'store_10',
#   'product': 'product_3',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(370.7833655699276)},
#  {'store': 'store_10',
#   'product': 'product_4',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(428.94706491533987)},
#  {'store': 'store_10',
#   'product': 'product_5',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(626.668561956767)},
#  {'store': 'store_10',
#   'product': 'product_6',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(621.6965587740722)},
#  {'store': 'store_10',
#   'product': 'product_7',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(589.7899746723936)},
#  {'store': 'store_10',
#   'product': 'product_8',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(413.02796697607056)},
#  {'store': 'store_10',
#   'product': 'product_9',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(405.5841499189622)},
#  {'store': 'store_2',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(611.4812949187103)},
#  {'store': 'store_2',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(620.0804028762385)},
#  {'store': 'store_2',
#   'product': 'product_11',
#   'p': 1,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(668.232082650868)},
#  {'store': 'store_2',
#   'product': 'product_12',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 2,
#   'D': 0,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(598.2624567080874)},
#  {'store': 'store_2',
#   'product': 'product_13',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(367.7355762147924)},
#  {'store': 'store_2',
#   'product': 'product_14',
#   'p': 1,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(674.5714541520151)},
#  {'store': 'store_2',
#   'product': 'product_15',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(624.1487807502637)},
#  {'store': 'store_2',
#   'product': 'product_16',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(610.1945897934361)},
#  {'store': 'store_2',
#   'product': 'product_17',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(407.1351120246677)},
#  {'store': 'store_2',
#   'product': 'product_18',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(624.0391362818053)},
#  {'store': 'store_2',
#   'product': 'product_19',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(636.8706123351938)},
#  {'store': 'store_2',
#   'product': 'product_2',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(610.6873254245413)},
#  {'store': 'store_2',
#   'product': 'product_20',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(615.9599043412087)},
#  {'store': 'store_2',
#   'product': 'product_3',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(438.71411457663146)},
#  {'store': 'store_2',
#   'product': 'product_4',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(385.5907244122483)},
#  {'store': 'store_2',
#   'product': 'product_5',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(597.805795564338)},
#  {'store': 'store_2',
#   'product': 'product_6',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(401.3644471356186)},
#  {'store': 'store_2',
#   'product': 'product_7',
#   'p': 0,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(611.0539724529742)},
#  {'store': 'store_2',
#   'product': 'product_8',
#   'p': 1,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(661.6904771627609)},
#  {'store': 'store_2',
#   'product': 'product_9',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(630.4928566505466)},
#  {'store': 'store_3',
#   'product': 'product_1',
#   'p': 0,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(641.7717304589403)},
#  {'store': 'store_3',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(619.5196027384035)},
#  {'store': 'store_3',
#   'product': 'product_11',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(650.762311867697)},
#  {'store': 'store_3',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(412.91336674858655)},
#  {'store': 'store_3',
#   'product': 'product_13',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(588.2459409601377)},
#  {'store': 'store_3',
#   'product': 'product_14',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(385.7477985387744)},
#  {'store': 'store_3',
#   'product': 'product_15',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(601.7808629584208)},
#  {'store': 'store_3',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(562.4283419443522)},
#  {'store': 'store_3',
#   'product': 'product_17',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(634.5315717885451)},
#  {'store': 'store_3',
#   'product': 'product_18',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(618.1023912590555)},
#  {'store': 'store_3',
#   'product': 'product_19',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(396.4403233074662)},
#  {'store': 'store_3',
#   'product': 'product_2',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(590.9259745910806)},
#  {'store': 'store_3',
#   'product': 'product_20',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(582.4397589967224)},
#  {'store': 'store_3',
#   'product': 'product_3',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(605.5304720525891)},
#  {'store': 'store_3',
#   'product': 'product_4',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(615.6708562444812)},
#  {'store': 'store_3',
#   'product': 'product_5',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(418.3701894540503)},
#  {'store': 'store_3',
#   'product': 'product_6',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(598.9054025304061)},
#  {'store': 'store_3',
#   'product': 'product_7',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(441.6415375482012)},
#  {'store': 'store_3',
#   'product': 'product_8',
#   'p': 1,
#   'd': 0,
#   'q': 2,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(614.617567881552)},
#  {'store': 'store_3',
#   'product': 'product_9',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(410.6261765096964)},
#  {'store': 'store_4',
#   'product': 'product_1',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(625.0346792231833)},
#  {'store': 'store_4',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(586.7282812066004)},
#  {'store': 'store_4',
#   'product': 'product_11',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(648.6097787468782)},
#  {'store': 'store_4',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(593.1422177051327)},
#  {'store': 'store_4',
#   'product': 'product_13',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(636.5074580455384)},
#  {'store': 'store_4',
#   'product': 'product_14',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(635.2245294682712)},
#  {'store': 'store_4',
#   'product': 'product_15',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(646.013104482633)},
#  {'store': 'store_4',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(411.2661152171936)},
#  {'store': 'store_4',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(399.237499412836)},
#  {'store': 'store_4',
#   'product': 'product_18',
#   'p': 2,
#   'd': 0,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(676.2460917719491)},
#  {'store': 'store_4',
#   'product': 'product_19',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(405.65372963832715)},
#  {'store': 'store_4',
#   'product': 'product_2',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(414.01510153031217)},
#  {'store': 'store_4',
#   'product': 'product_20',
#   'p': 2,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(409.5060079590253)},
#  {'store': 'store_4',
#   'product': 'product_3',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(603.8593568953515)},
#  {'store': 'store_4',
#   'product': 'product_4',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(630.3613088632933)},
#  {'store': 'store_4',
#   'product': 'product_5',
#   'p': 1,
#   'd': 0,
#   'q': 2,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(603.1319442962177)},
#  {'store': 'store_4',
#   'product': 'product_6',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(668.8515893481697)},
#  {'store': 'store_4',
#   'product': 'product_7',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(650.1661757756344)},
#  {'store': 'store_4',
#   'product': 'product_8',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(437.57525893423974)},
#  {'store': 'store_4',
#   'product': 'product_9',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(394.12201989222996)},
#  {'store': 'store_5',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(596.3216995214302)},
#  {'store': 'store_5',
#   'product': 'product_10',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(580.1102110252132)},
#  {'store': 'store_5',
#   'product': 'product_11',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(597.0569456343296)},
#  {'store': 'store_5',
#   'product': 'product_12',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(644.3467758856326)},
#  {'store': 'store_5',
#   'product': 'product_13',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(405.47123227950124)},
#  {'store': 'store_5',
#   'product': 'product_14',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(596.7725035721385)},
#  {'store': 'store_5',
#   'product': 'product_15',
#   'p': 3,
#   'd': 1,
#   'q': 2,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(666.4714089386882)},
#  {'store': 'store_5',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(402.4279625959217)},
#  {'store': 'store_5',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(404.0733049920791)},
#  {'store': 'store_5',
#   'product': 'product_18',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(421.47521808245216)},
#  {'store': 'store_5',
#   'product': 'product_19',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(616.5821641344664)},
#  {'store': 'store_5',
#   'product': 'product_2',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(426.7623270492976)},
#  {'store': 'store_5',
#   'product': 'product_20',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(395.71648082078525)},
#  {'store': 'store_5',
#   'product': 'product_3',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(605.4710454434235)},
#  {'store': 'store_5',
#   'product': 'product_4',
#   'p': 1,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(630.7442271739408)},
#  {'store': 'store_5',
#   'product': 'product_5',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(416.1876352172106)},
#  {'store': 'store_5',
#   'product': 'product_6',
#   'p': 2,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(617.9891865998158)},
#  {'store': 'store_5',
#   'product': 'product_7',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(599.8037084258801)},
#  {'store': 'store_5',
#   'product': 'product_8',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 2,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(597.8958011882653)},
#  {'store': 'store_5',
#   'product': 'product_9',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(576.5057971121578)},
#  {'store': 'store_6',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(609.9451792767504)},
#  {'store': 'store_6',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(623.0008802221979)},
#  {'store': 'store_6',
#   'product': 'product_11',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(440.4196683167492)},
#  {'store': 'store_6',
#   'product': 'product_12',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(623.9739376743104)},
#  {'store': 'store_6',
#   'product': 'product_13',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(629.0561335221835)},
#  {'store': 'store_6',
#   'product': 'product_14',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(418.84982619271045)},
#  {'store': 'store_6',
#   'product': 'product_15',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(429.74174111516174)},
#  {'store': 'store_6',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(412.1882273117077)},
#  {'store': 'store_6',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(594.2563757481178)},
#  {'store': 'store_6',
#   'product': 'product_18',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(389.6061652613697)},
#  {'store': 'store_6',
#   'product': 'product_19',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(417.53314783664445)},
#  {'store': 'store_6',
#   'product': 'product_2',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(377.9240859681372)},
#  {'store': 'store_6',
#   'product': 'product_20',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(612.1883729193885)},
#  {'store': 'store_6',
#   'product': 'product_3',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(583.5502319712308)},
#  {'store': 'store_6',
#   'product': 'product_4',
#   'p': 3,
#   'd': 1,
#   'q': 3,
#   'P': 1,
#   'D': 0,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(649.7051479971335)},
#  {'store': 'store_6',
#   'product': 'product_5',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(618.863454386337)},
#  {'store': 'store_6',
#   'product': 'product_6',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(611.5329074654616)},
#  {'store': 'store_6',
#   'product': 'product_7',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(622.3581389501278)},
#  {'store': 'store_6',
#   'product': 'product_8',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(595.0766491862194)},
#  {'store': 'store_6',
#   'product': 'product_9',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(396.4039868770054)},
#  {'store': 'store_7',
#   'product': 'product_1',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(411.3656627019479)},
#  {'store': 'store_7',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(611.5669447618933)},
#  {'store': 'store_7',
#   'product': 'product_11',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(401.3501117796844)},
#  {'store': 'store_7',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(431.8457192338992)},
#  {'store': 'store_7',
#   'product': 'product_13',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(403.3062028717882)},
#  {'store': 'store_7',
#   'product': 'product_14',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(620.6418067420913)},
#  {'store': 'store_7',
#   'product': 'product_15',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(394.590259648606)},
#  {'store': 'store_7',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(402.8406521331573)},
#  {'store': 'store_7',
#   'product': 'product_17',
#   'p': 1,
#   'd': 1,
#   'q': 1,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(640.8030056116514)},
#  {'store': 'store_7',
#   'product': 'product_18',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(606.6701596550884)},
#  {'store': 'store_7',
#   'product': 'product_19',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(598.7711114754434)},
#  {'store': 'store_7',
#   'product': 'product_2',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(394.8126716835556)},
#  {'store': 'store_7',
#   'product': 'product_20',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(620.7424702160648)},
#  {'store': 'store_7',
#   'product': 'product_3',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(426.585497781235)},
#  {'store': 'store_7',
#   'product': 'product_4',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(584.697078512236)},
#  {'store': 'store_7',
#   'product': 'product_5',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(562.5714687777722)},
#  {'store': 'store_7',
#   'product': 'product_6',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(603.1880450039869)},
#  {'store': 'store_7',
#   'product': 'product_7',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(388.59903328882154)},
#  {'store': 'store_7',
#   'product': 'product_8',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(613.7218474850039)},
#  {'store': 'store_7',
#   'product': 'product_9',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(404.94770838325536)},
#  {'store': 'store_8',
#   'product': 'product_1',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(645.8842063021947)},
#  {'store': 'store_8',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(615.3099079075478)},
#  {'store': 'store_8',
#   'product': 'product_11',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(632.1078736181452)},
#  {'store': 'store_8',
#   'product': 'product_12',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(599.4099727829898)},
#  {'store': 'store_8',
#   'product': 'product_13',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(440.2343246264224)},
#  {'store': 'store_8',
#   'product': 'product_14',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 0,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(619.325645607134)},
#  {'store': 'store_8',
#   'product': 'product_15',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(636.8005111936844)},
#  {'store': 'store_8',
#   'product': 'product_16',
#   'p': 0,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(663.5014079388301)},
#  {'store': 'store_8',
#   'product': 'product_17',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(390.1067806385746)},
#  {'store': 'store_8',
#   'product': 'product_18',
#   'p': 1,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(651.3062244998401)},
#  {'store': 'store_8',
#   'product': 'product_19',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(403.6923231611158)},
#  {'store': 'store_8',
#   'product': 'product_2',
#   'p': 3,
#   'd': 1,
#   'q': 1,
#   'P': 0,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(606.9647499561667)},
#  {'store': 'store_8',
#   'product': 'product_20',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(624.7761117063919)},
#  {'store': 'store_8',
#   'product': 'product_3',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(420.862984039113)},
#  {'store': 'store_8',
#   'product': 'product_4',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(398.1159832305935)},
#  {'store': 'store_8',
#   'product': 'product_5',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(399.5741059962086)},
#  {'store': 'store_8',
#   'product': 'product_6',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(426.77455685850146)},
#  {'store': 'store_8',
#   'product': 'product_7',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(417.6546527756133)},
#  {'store': 'store_8',
#   'product': 'product_8',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(633.9382643492435)},
#  {'store': 'store_8',
#   'product': 'product_9',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(425.4866977495061)},
#  {'store': 'store_9',
#   'product': 'product_1',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(352.4499648863996)},
#  {'store': 'store_9',
#   'product': 'product_10',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(649.0911505541325)},
#  {'store': 'store_9',
#   'product': 'product_11',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(413.2969197745783)},
#  {'store': 'store_9',
#   'product': 'product_12',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(393.0104956182156)},
#  {'store': 'store_9',
#   'product': 'product_13',
#   'p': 1,
#   'd': 0,
#   'q': 0,
#   'P': 1,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(401.05764665461277)},
#  {'store': 'store_9',
#   'product': 'product_14',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(610.8805461362157)},
#  {'store': 'store_9',
#   'product': 'product_15',
#   'p': 0,
#   'd': 0,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(658.1321817682193)},
#  {'store': 'store_9',
#   'product': 'product_16',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(621.9683519436403)},
#  {'store': 'store_9',
#   'product': 'product_17',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(595.3080928257061)},
#  {'store': 'store_9',
#   'product': 'product_18',
#   'p': 0,
#   'd': 1,
#   'q': 1,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(647.4673571302798)},
#  {'store': 'store_9',
#   'product': 'product_19',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(607.1517122844623)},
#  {'store': 'store_9',
#   'product': 'product_2',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 2,
#   's': 4,
#   'AIC': np.float64(437.6270425659229)},
#  {'store': 'store_9',
#   'product': 'product_20',
#   'p': 2,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(373.8612851838441)},
#  {'store': 'store_9',
#   'product': 'product_3',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(424.5895439913098)},
#  {'store': 'store_9',
#   'product': 'product_4',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(622.6119001238011)},
#  {'store': 'store_9',
#   'product': 'product_5',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(623.2825706314401)},
#  {'store': 'store_9',
#   'product': 'product_6',
#   'p': 1,
#   'd': 0,
#   'q': 1,
#   'P': 2,
#   'D': 1,
#   'Q': 0,
#   's': 4,
#   'AIC': np.float64(545.8407013389282)},
#  {'store': 'store_9',
#   'product': 'product_7',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 2,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(625.2653511116774)},
#  {'store': 'store_9',
#   'product': 'product_8',
#   'p': 3,
#   'd': 1,
#   'q': 0,
#   'P': 1,
#   'D': 0,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(641.3166772794718)},
#  {'store': 'store_9',
#   'product': 'product_9',
#   'p': 0,
#   'd': 0,
#   'q': 0,
#   'P': 0,
#   'D': 1,
#   'Q': 1,
#   's': 4,
#   'AIC': np.float64(413.8486720491281)}]

# %%
sarima_params = pd.DataFrame(results)
sarima_params
# Out:
#        store     product  p  d  q  P  D  Q  s         AIC
# 0    store_1   product_1  0  0  0  2  1  0  4  619.839358
# 1    store_1  product_10  1  0  0  2  1  1  4  401.287710
# 2    store_1  product_11  0  0  0  2  1  0  4  411.292456
# 3    store_1  product_12  0  0  0  2  1  0  4  411.801787
# 4    store_1  product_13  3  1  0  2  0  1  4  659.088151
# ..       ...         ... .. .. .. .. .. .. ..         ...
# 195  store_9   product_5  3  1  0  2  0  1  4  623.282571
# 196  store_9   product_6  1  0  1  2  1  0  4  545.840701
# 197  store_9   product_7  3  1  0  2  0  1  4  625.265351
# 198  store_9   product_8  3  1  0  1  0  1  4  641.316677
# 199  store_9   product_9  0  0  0  0  1  1  4  413.848672
#
# [200 rows x 10 columns]

# %%
# Extract numeric parts
sarima_params["store_num"] = sarima_params["store"].str.extract(r"(\d+)").astype(int)
sarima_params["product_num"] = sarima_params["product"].str.extract(r"(\d+)").astype(int)

# Sort numerically
sarima_params = sarima_params.sort_values(
    ["store_num", "product_num"]
).reset_index(drop=True)

# Drop helper columns
sarima_params = sarima_params.drop(columns=["store_num", "product_num"])

# %%
sarima_params
# Out:
#         store     product  p  d  q  P  D  Q  s         AIC
# 0     store_1   product_1  0  0  0  2  1  0  4  619.839358
# 1     store_1   product_2  3  1  0  1  0  2  4  613.373889
# 2     store_1   product_3  3  1  0  1  0  1  4  633.360471
# 3     store_1   product_4  2  1  1  0  0  0  4  648.748650
# 4     store_1   product_5  2  1  0  1  0  1  4  650.334450
# ..        ...         ... .. .. .. .. .. .. ..         ...
# 195  store_10  product_16  0  0  0  2  1  0  4  440.626786
# 196  store_10  product_17  0  0  0  0  1  1  4  396.836732
# 197  store_10  product_18  3  1  1  0  0  2  4  623.407665
# 198  store_10  product_19  1  0  0  2  1  0  4  606.087323
# 199  store_10  product_20  0  0  0  2  1  1  4  608.175397
#
# [200 rows x 10 columns]

# %%
sarima_params.to_csv("sarima_params.csv", index=False)

# %% [markdown]
# ## Forecasting

# %%
df = pd.read_csv("demand_data.csv", parse_dates=["week"])
params_df = pd.read_csv("sarima_params.csv")

# Extract numeric parts
df["store_num"] = df["store"].str.extract(r"(\d+)").astype(int)
df["product_num"] = df["product"].str.extract(r"(\d+)").astype(int)

# Correct numeric sorting
df = df.sort_values(["store_num", "product_num", "week"])

df = df.drop(columns=["store_num", "product_num"])

forecast_results = []

# -----------------------------
# Forecast per store-product
# -----------------------------
for _, row in params_df.iterrows():

    store = row["store"]
    product = row["product"]

    p, d, q = int(row["p"]), int(row["d"]), int(row["q"])
    P, D, Q, s = int(row["P"]), int(row["D"]), int(row["Q"]), int(row["s"])

    g = df[(df["store"] == store) & (df["product"] == product)]

    # Ensure full 100 weeks exist
    if len(g) < 100:
        continue

    # Train: weeks 1–90
    train = g.iloc[:90]["demand"].values

    try:
        model = SARIMAX(
            train,
            order=(p, d, q),
            seasonal_order=(P, D, Q, s),
            enforce_stationarity=False,
            enforce_invertibility=False
        )

        res = model.fit(disp=False)

        # Forecast weeks 91–100
        forecast = res.forecast(steps=10)

        forecast_weeks = g.iloc[90:100]["week"].values

        for week, value in zip(forecast_weeks, forecast):
            forecast_results.append({
                "store": store,
                "product": product,
                "week": week,
                "forecast_demand": max(0, int(round(value)))
            })

    except Exception as e:
        print(f"Forecast failed for {store}-{product}: {e}")


forecast_df = pd.DataFrame(forecast_results)

forecast_df.head()
# Out:
#      store    product       week  forecast_demand
# 0  store_1  product_1 2025-09-28              227
# 1  store_1  product_1 2025-10-05              222
# 2  store_1  product_1 2025-10-12              198
# 3  store_1  product_1 2025-10-19              190
# 4  store_1  product_1 2025-10-26              235

# %%
forecast_df
# Out:
#         store    product       week  forecast_demand
# 0     store_1  product_1 2025-09-28              227
# 1     store_1  product_1 2025-10-05              222
# 2     store_1  product_1 2025-10-12              198
# 3     store_1  product_1 2025-10-19              190
# 4     store_1  product_1 2025-10-26              235
# ...       ...        ...        ...              ...
# 1995  store_9  product_9 2025-11-02              201
# 1996  store_9  product_9 2025-11-09              190
# 1997  store_9  product_9 2025-11-16              194
# 1998  store_9  product_9 2025-11-23              200
# 1999  store_9  product_9 2025-11-30              201
#
# [2000 rows x 4 columns]

# %%
forecast_df.to_csv("sarima_forecast.csv", index=False)

# %%
# Actual demand data (weeks 91–100 only)
actual_df = df[["store", "product", "week", "demand"]].rename(
    columns={"demand": "actual_demand"}
)

# %%
forecast_with_actual = forecast_df.merge(
    actual_df,
    on=["store", "product", "week"],
    how="left"
)

# %%
forecast_with_actual
# Out:
#         store    product       week  forecast_demand  actual_demand
# 0     store_1  product_1 2025-09-28              227            212
# 1     store_1  product_1 2025-10-05              222            216
# 2     store_1  product_1 2025-10-12              198            201
# 3     store_1  product_1 2025-10-19              190            193
# 4     store_1  product_1 2025-10-26              235            219
# ...       ...        ...        ...              ...            ...
# 1995  store_9  product_9 2025-11-02              201            211
# 1996  store_9  product_9 2025-11-09              190            204
# 1997  store_9  product_9 2025-11-16              194            195
# 1998  store_9  product_9 2025-11-23              200            212
# 1999  store_9  product_9 2025-11-30              201            217
#
# [2000 rows x 5 columns]

# %% [markdown]
# ## Accuracy

# %%
df_eval = forecast_with_actual.copy()
df_eval = df_eval[df_eval["actual_demand"] > 0]

df_eval["APE"] = (
    np.abs(df_eval["actual_demand"] - df_eval["forecast_demand"])
    / df_eval["actual_demand"]
)

MAPE = df_eval["APE"].mean() * 100
print(f"MAPE: {MAPE:.2f}%")
# Out:
# MAPE: 7.58%

# %%
accuracy = 100 - MAPE
print(f"Forecast Accuracy: {accuracy:.2f}%")
# Out:
# Forecast Accuracy: 92.42%
